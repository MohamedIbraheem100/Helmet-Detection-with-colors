# %%
# !pip install Roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.5/169.5 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 95.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 134.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="cqJWeefJx0t8C6LHDGqy")
project = rf.workspace("hemaz").project("safety-helmet-q3b8o-s4sli")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to safety-helmet-1 in yolov8:: 100%|██████████| 2847/2847 [00:00<00:00, 4132.01it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# !yolo task=detect mode=train model=yolov8n.pt data=/content/safety-helmet-1/data.yaml epochs=50 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1798.0±459.1 MB/s, size: 38.9 KB)
# val: Scanning /content/safety-helmet-1/valid/labels.cache... 140 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 140/140 29.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.7it/s 2.4s
#                    all        140        356      0.949      0.962      0.973      0.726
#                 Helmet        109        198      0.985      0.982      0.988      0.769
#              NO-Helmet         31        158      0.914      0.942      0.957      0.682
# Speed: 3.0ms preprocess, 5.0ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to /content/runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml source={dataset.location}/test/images save_txt=true save=true
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/138 /content/safety-helmet-1/test/images/0_19421787_jpg.rf.a0f1b2a3917ab9aa6b10b3c12c02f104.jpg: 640x640 1 Helmet, 14.1ms
# image 2/138 /content/safety-helmet-1/test/images/0_49417216_jpg.rf.e59c58f247399370d38cbc68deb13a2c.jpg: 640x640 1 Helmet, 7.8ms
# image 3/138 /content/safety-helmet-1/test/images/0_51085743_jpg.rf.4d2259cbfab6e95c04c7469635b40816.jpg: 640x640 1 Helmet, 8.0ms
# image 4/138 /content/safety-helmet-1/test/images/0_59535521_jpg.rf.2c868b3db42d4dbaeb3adbca77bed19b.jpg: 640x640 1 Helmet, 8.2ms
# image 5/138 /content/safety-helmet-1/test/images/1_78404089_jpg.rf.365ab30b7017c47714b2fe695897f157.jpg: 640x640 1 Helmet, 8.6ms
# image 6/138 /content/safety-helmet-1/test/images/20221206_094638_jpg.rf.d41cb1dd2dac545655563c489ae8e2f2.jpg: 640x640 1 Helmet, 8.9ms
# ...

# %%
# !zip -r /content/runs /content/
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2026.03.30/ (stored 0%)
#   adding: content/.config/logs/2026.03.30/13.34.38.846859.log (deflated 56%)
#   adding: content/.config/logs/2026.03.30/13.34.38.057647.log (deflated 57%)
#   adding: content/.config/logs/2026.03.30/13.33.51.299064.log (deflated 92%)
#   adding: content/.config/logs/2026.03.30/13.34.25.289195.log (deflated 87%)
#   adding: content/.config/logs/2026.03.30/13.34.14.816231.log (deflated 58%)
#   adding: content/.config/logs/2026.03.30/13.34.26.856841.log (deflated 58%)
#   adding: content/.config/config_sentinel (stored 0%)
# ...

# %%
from google.colab import files

files.download("/content/runs.zip")
